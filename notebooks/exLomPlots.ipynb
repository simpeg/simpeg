# %%
import sys
sys.path.append('../')

import numpy as np
import matplotlib.pyplot as plt
from SimPEG import LogicallyOrthogonalMesh, utils, exampleLomGird
mkvc = utils.mkvc

# %% [markdown]
# ## Test 2D Plots
#
# For 2D nodal or cell-centered plots are supported.

# %%
X, Y = exampleLomGird([3,3],'rotate')
M = LogicallyOrthogonalMesh([X, Y])

# %%
M.plotGrid()

# %% [markdown]
# ## Test 3D Plots
#
# Plot x, y, and z coordinates of cell-centred points

# %%
X, Y, Z = exampleLomGird([3,3,3],'rotate')
M = LogicallyOrthogonalMesh([X, Y, Z])

# %%
M.plotGrid()
